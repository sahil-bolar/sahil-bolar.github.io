# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,1,100)
y1 = x
y2 = x**2
y3 = x**3
plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)
plt.title('testing blah blah blah')
# Out:
# Text(0.5, 1.0, 'testing blah blah blah')
